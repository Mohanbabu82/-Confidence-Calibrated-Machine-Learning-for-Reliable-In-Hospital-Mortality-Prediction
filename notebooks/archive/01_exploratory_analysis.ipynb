# %% [markdown]
# # Exploratory Analysis — Confidence-Calibrated Mortality Prediction
#
# This notebook does not include or download any real patient data. Point `configs/config.yaml -> paths.data_raw` at your own local, governance-approved dataset before running.

# %%
import sys
sys.path.append('..')

from src.reproducibility import set_global_seed, get_logger, log_run_metadata
from src.config import load_config

set_global_seed(42)
logger = get_logger()
config = load_config()
log_run_metadata(seed=42)
logger.info('Notebook initialized with seed=42')

# %%
from src.data_loader import load_raw_data

# This will raise FileNotFoundError until a real local dataset is supplied
# at the path configured in configs/config.yaml -> paths.data_raw
df = load_raw_data(config)
df.head()
